# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import cartopy.crs as ccrs
import geoviews as gv # noqa
import pyproj


# Import API key
from api_keys import geoapify_key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 6
#       4 import requests
#       5 import cartopy.crs as ccrs
# ----> 6 import geoviews as gv # noqa
#       7 import pyproj
#      10 # Import API key
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/__init__.py:9
#       3 from holoviews import (extension, help, opts, output, renderer, Store, # noqa (API import)
#       4                        Cycle, Palette, Overlay, Layout, NdOverlay, NdLayout,
#       5                        HoloMap, DynamicMap, GridSpace, Dimension, dim)
#       7 from holoviews import render, save # noqa (API import)
# ----> 9 from .annotators import annotate # noqa (API import)
#      10 from .element import ( # noqa (API import)
#      11     _Element, Feature, Tiles, WMTS, LineContours, FilledContours,
#      12     Text, Image, Points, Path, Polygons, Shape, Dataset, RGB,
#      13     Contours, Graph, TriMesh, Nodes, EdgePaths, QuadMesh, VectorField,
#      14     HexTiles, Labels, Rectangles, Segments, WindBarbs
#      15 )
#      16 from .util import load_tiff, from_xarray # noqa (API import)
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/annotators.py:15
#      13 from .models.custom_tools import CheckpointTool, RestoreTool, ClearTool
#      14 from .links import VertexTableLink, PointTableLink, HvRectanglesTableLink, RectanglesTableLink
# ---> 15 from .operation import project
#      16 from .streams import PolyVertexDraw, PolyVertexEdit
#      18 Annotator._tools = [CheckpointTool, RestoreTool, ClearTool]
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/operation/__init__.py:7
#       5 from .. import element as gv_element
#       6 from ..element import _Element
# ----> 7 from .projection import ( # noqa (API import)
#       8     project_image, project_path, project_shape, project_points,
#       9     project_graph, project_quadmesh, project_geom, project)
#      10 from .resample import resample_geometry # noqa (API import)
#      12 geo_ops = [contours, bivariate_kde]
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/operation/projection.py:15
#      12 from shapely.geometry import Polygon, MultiPolygon
#      13 from shapely.geometry.collection import GeometryCollection
# ---> 15 from ..data import GeoPandasInterface
#      16 from ..element import (Image, Shape, Polygons, Path, Points, Contours,
#      17                        RGB, Graph, Nodes, EdgePaths, QuadMesh, VectorField,
#      18                        HexTiles, Labels, Rectangles, Segments)
#      19 from ..util import (
#      20     project_extents, path_to_geom_dicts, polygons_to_geom_dicts,
#      21     geom_dict_to_array_dict
#      22 )
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/data/__init__.py:2
#       1 from .geom_dict import GeomDictInterface # noqa (API import)
# ----> 2 from .geopandas import GeoPandasInterface # noqa (API import)
#       3 from .iris import CubeInterface
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/data/geopandas.py:10
#       7 import pandas as pd
#       9 from holoviews.core.util import isscalar, unique_iterator, unique_array
# ---> 10 from holoviews.core.data import Dataset, Interface, MultiInterface, PandasAPI
#      11 from holoviews.core.data.interface import DataError
#      12 from holoviews.core.data import PandasInterface
#
# ImportError: cannot import name 'PandasAPI' from 'holoviews.core.data' (/Users/gori/anaconda3/envs/EdX/lib/python3.10/site-packages/holoviews/core/data/__init__.py)

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       college  64.8569 -147.8028     48.15        91         100
# 1        1        gidole   5.6500   37.3667     59.00        80          64
# 2        2        kodiak  57.7900 -152.4072     53.11        58          40
# 3        3         khovd  48.0056   91.6419     53.04        37          52
# 4        4  richards bay -28.7830   32.0377     61.32        75           1
#
#    Wind Speed Country        Date
# 0        9.22      US  1694031402
# 1        1.66      ET  1694031402
# 2        6.91      US  1694031403
# 3        8.55      MN  1694031403
# 4        3.98      ZA  1694031403

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
p1 = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = "EsriUSATopo",
    frame_width = 700,
    frame_height = 500,
    size = 'Humidity',
    color = 'City',
    alpha = 0.7
)

# Display the map
p1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/util.py:231, in process_crs(crs)
#     230 import cartopy.crs as ccrs
# --> 231 import geoviews as gv # noqa
#     232 import pyproj
#
# ModuleNotFoundError: No module named 'geoviews'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Configure the map plot
# ----> 2 p1 = city_data_df.hvplot.points(
#       3     'Lng',
#       4     'Lat',
#       5     geo = True,
#       6     tiles = "EsriUSATopo",
#       7     frame_width = 700,
#       8     frame_height = 500,
#       9     size = 'Humidity',
#      10     color = 'City',
#      11     alpha = 0.7
#      12 )
#      14 # Display the map
#      15 p1
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/plotting/core.py:1612, in hvPlotTabular.points(self, x, y, **kwds)
#    1554 def points(self, x=None, y=None, **kwds):
#    1555     """
#    1556     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1557     geographic plots.
#    (...)
#    1610     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1611     """
# -> 1612     return self(x, y, kind="points", **kwds)
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/plotting/core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/plotting/core.py:99, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#      97 y = y or params.pop("y", None)
#      98 kind = kind or params.pop("kind", None)
# ---> 99 return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/converter.py:396, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394 self.dynamic = dynamic
#     395 self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396 self.crs = self._process_crs(data, crs) if self.geo else None
#     397 self.project = project
#     398 self.coastline = coastline
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/converter.py:650, in HoloViewsConverter._process_crs(self, data, crs)
#     647     _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     649 try:
# --> 650     return process_crs(_crs)
#     651 except ValueError:
#     652     # only raise error if crs was specified in kwargs
#     653     if crs:
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/util.py:234, in process_crs(crs)
#     232     import pyproj
#     233 except ImportError:
# --> 234     raise ImportError('Geographic projection support requires GeoViews, pyproj and cartopy.')
#     236 if crs is None:
#     237     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires GeoViews, pyproj and cartopy.

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
clean_df = city_data_df.loc[city_data_df['Max Temp'] <= 40]

# Drop any rows with null values

clean_df = clean_df.dropna()

# Display sample data
clean_df
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 8          8            udachny  66.4167  112.4000     30.45       100
# 15        15          grytviken -54.2811  -36.5092     22.30        76
# 17        17  port-aux-francais -49.3500   70.2167     37.87        70
# 19        19          ilulissat  69.2167  -51.1000     35.62        93
# 40        40             aykhal  66.0000  111.5000     26.44        95
# 44        44              tiksi  71.6872  128.8694     36.00        89
# 59        59            talnakh  69.4865   88.3972     38.21        78
# 68        68           vilyuysk  63.7553  121.6247     26.55        96
# 85        85           khandyga  62.6667  135.6000     39.38        95
# 134      134            dudinka  69.4058   86.1778     38.62        70
# 167      167       longyearbyen  78.2186   15.6401     37.24        93
# 176      176           bilibino  68.0546  166.4372     33.24        69
# 184      184            aasiaat  68.7098  -52.8699     34.56        99
# 240      240        el calafate -50.3408  -72.2768     35.92        97
# 256      256              nagqu  31.5000   92.0000     35.83        81
# 339      339             namtsy  62.7161  129.6658     37.83        60
# 372      372               amga  60.8953  131.9608     37.51        91
# 422      422     chernyshevskiy  63.0128  112.4714     25.83        83
# 461      461         olyokminsk  60.3736  120.4264     28.17        91
# 498      498    verkhnevilyuysk  63.4453  120.3167     25.93        96
#
#      Cloudiness  Wind Speed Country        Date
# 8           100       18.19      RU  1694031404
# 15           30       10.85      GS  1694031406
# 17          100       13.38      TF  1694031407
# 19          100        3.44      GL  1694031408
# 40          100       12.06      RU  1694031412
# 44           25       19.89      RU  1694031417
# 59            9        2.55      RU  1694031421
# 68           16        5.17      RU  1694031423
# 85          100        7.83      RU  1694031426
# 134          63        3.00      RU  1694031433
# 167          75       24.16      SJ  1694031441
# 176           3        1.43      RU  1694031443
# 184         100        4.52      GL  1694031444
# 240         100        2.89      AR  1694031453
# 256          99        4.56      CN  1694031456
# 339          99        8.70      RU  1694031474
# 372          86        2.13      RU  1694031486
# 422           9        3.29      RU  1694031493
# 461           8        0.22      RU  1694031499
# 498          19        4.83      RU  1694031509

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = clean_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
# /var/folders/xz/bm6jnq215_s3fm_f2h0lbhgc0000gq/T/ipykernel_4450/1385115104.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = ''
#                   City Country      Lat       Lng  Humidity Hotel Name
# 8              udachny      RU  66.4167  112.4000       100
# 15           grytviken      GS -54.2811  -36.5092        76
# 17   port-aux-francais      TF -49.3500   70.2167        70
# 19           ilulissat      GL  69.2167  -51.1000        93
# 40              aykhal      RU  66.0000  111.5000        95
# 44               tiksi      RU  71.6872  128.8694        89
# 59             talnakh      RU  69.4865   88.3972        78
# 68            vilyuysk      RU  63.7553  121.6247        96
# 85            khandyga      RU  62.6667  135.6000        95
# 134            dudinka      RU  69.4058   86.1778        70
# 167       longyearbyen      SJ  78.2186   15.6401        93
# 176           bilibino      RU  68.0546  166.4372        69
# 184            aasiaat      GL  68.7098  -52.8699        99
# 240        el calafate      AR -50.3408  -72.2768        97
# 256              nagqu      CN  31.5000   92.0000        81
# 339             namtsy      RU  62.7161  129.6658        60
# 372               amga      RU  60.8953  131.9608        91
# 422     chernyshevskiy      RU  63.0128  112.4714        83
# 461         olyokminsk      RU  60.3736  120.4264        91
# 498    verkhnevilyuysk      RU  63.4453  120.3167        96

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 #10,000 meters
params = {
    "categories": "accommodation.hotel",
    'apiKey': geoapify_key,
    "limit": 1
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = hotel_df.loc[index, 'Lat']
    lon = hotel_df.loc[index, 'Lng']

    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# udachny - nearest hotel: Вилюй
# grytviken - nearest hotel: No hotel found
# port-aux-francais - nearest hotel: Keravel
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# aykhal - nearest hotel: Уют
# tiksi - nearest hotel: Арктика
# talnakh - nearest hotel: Талнах
# vilyuysk - nearest hotel: Мария
# khandyga - nearest hotel: Апельсин
# dudinka - nearest hotel: Виктория
# longyearbyen - nearest hotel: The Vault
# bilibino - nearest hotel: No hotel found
# aasiaat - nearest hotel: SØMA
# el calafate - nearest hotel: Hostería Las Avutardas
# nagqu - nearest hotel: Naqu Hotel
# namtsy - nearest hotel: No hotel found
# amga - nearest hotel: "АммА"
# chernyshevskiy - nearest hotel: No hotel found
# olyokminsk - nearest hotel: Колос
# verkhnevilyuysk - nearest hotel: No hotel found
#                   City Country      Lat       Lng  Humidity  \
# 8              udachny      RU  66.4167  112.4000       100
# 15           grytviken      GS -54.2811  -36.5092        76
# 17   port-aux-francais      TF -49.3500   70.2167        70
# 19           ilulissat      GL  69.2167  -51.1000        93
# 40              aykhal      RU  66.0000  111.5000        95
# 44               tiksi      RU  71.6872  128.8694        89
# 59             talnakh      RU  69.4865   88.3972        78
# 68            vilyuysk      RU  63.7553  121.6247        96
# 85            khandyga      RU  62.6667  135.6000        95
# 134            dudinka      RU  69.4058   86.1778        70
# 167       longyearbyen      SJ  78.2186   15.6401        93
# 176           bilibino      RU  68.0546  166.4372        69
# 184            aasiaat      GL  68.7098  -52.8699        99
# 240        el calafate      AR -50.3408  -72.2768        97
# 256              nagqu      CN  31.5000   92.0000        81
# 339             namtsy      RU  62.7161  129.6658        60
# 372               amga      RU  60.8953  131.9608        91
# 422     chernyshevskiy      RU  63.0128  112.4714        83
# 461         olyokminsk      RU  60.3736  120.4264        91
# 498    verkhnevilyuysk      RU  63.4453  120.3167        96
#
#                             Hotel Name
# 8                                Вилюй
# 15                      No hotel found
# 17                             Keravel
# 19   Best Western Plus Hotel Ilulissat
# 40                                 Уют
# 44                             Арктика
# 59                              Талнах
# 68                               Мария
# 85                            Апельсин
# 134                           Виктория
# 167                          The Vault
# 176                     No hotel found
# 184                               SØMA
# 240             Hostería Las Avutardas
# 256                         Naqu Hotel
# 339                     No hotel found
# 372                             "АммА"
# 422                     No hotel found
# 461                              Колос
# 498                     No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
p2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 2,
    alpha = 0.7,
    color = 'City',
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
p2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/util.py:231, in process_crs(crs)
#     230 import cartopy.crs as ccrs
# --> 231 import geoviews as gv # noqa
#     232 import pyproj
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/__init__.py:9
#       7 from holoviews import render, save # noqa (API import)
# ----> 9 from .annotators import annotate # noqa (API import)
#      10 from .element import ( # noqa (API import)
#      11     _Element, Feature, Tiles, WMTS, LineContours, FilledContours,
#      12     Text, Image, Points, Path, Polygons, Shape, Dataset, RGB,
#      13     Contours, Graph, TriMesh, Nodes, EdgePaths, QuadMesh, VectorField,
#      14     HexTiles, Labels, Rectangles, Segments, WindBarbs
#      15 )
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/annotators.py:15
#      14 from .links import VertexTableLink, PointTableLink, HvRectanglesTableLink, RectanglesTableLink
# ---> 15 from .operation import project
#      16 from .streams import PolyVertexDraw, PolyVertexEdit
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/operation/__init__.py:7
#       6 from ..element import _Element
# ----> 7 from .projection import ( # noqa (API import)
#       8     project_image, project_path, project_shape, project_points,
#       9     project_graph, project_quadmesh, project_geom, project)
#      10 from .resample import resample_geometry # noqa (API import)
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/operation/projection.py:15
#      13 from shapely.geometry.collection import GeometryCollection
# ---> 15 from ..data import GeoPandasInterface
#      16 from ..element import (Image, Shape, Polygons, Path, Points, Contours,
#      17                        RGB, Graph, Nodes, EdgePaths, QuadMesh, VectorField,
#      18                        HexTiles, Labels, Rectangles, Segments)
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/data/__init__.py:2
#       1 from .geom_dict import GeomDictInterface # noqa (API import)
# ----> 2 from .geopandas import GeoPandasInterface # noqa (API import)
#       3 from .iris import CubeInterface
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/geoviews/data/geopandas.py:10
#       9 from holoviews.core.util import isscalar, unique_iterator, unique_array
# ---> 10 from holoviews.core.data import Dataset, Interface, MultiInterface, PandasAPI
#      11 from holoviews.core.data.interface import DataError
#
# ImportError: cannot import name 'PandasAPI' from 'holoviews.core.data' (/Users/gori/anaconda3/envs/EdX/lib/python3.10/site-packages/holoviews/core/data/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Configure the map plot
# ----> 2 p2 = hotel_df.hvplot.points(
#       3     "Lng",
#       4     "Lat",
#       5     geo = True,
#       6     tiles = "OSM",
#       7     frame_width = 800,
#       8     frame_height = 600,
#       9     size = "Humidity",
#      10     scale = 2,
#      11     alpha = 0.7,
#      12     color = 'City',
#      13     hover_cols = ["Hotel Name", "Country"]
#      14 )
#      16 # Display the map
#      17 p2
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/plotting/core.py:1612, in hvPlotTabular.points(self, x, y, **kwds)
#    1554 def points(self, x=None, y=None, **kwds):
#    1555     """
#    1556     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1557     geographic plots.
#    (...)
#    1610     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1611     """
# -> 1612     return self(x, y, kind="points", **kwds)
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/plotting/core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/plotting/core.py:99, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#      97 y = y or params.pop("y", None)
#      98 kind = kind or params.pop("kind", None)
# ---> 99 return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/converter.py:396, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394 self.dynamic = dynamic
#     395 self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396 self.crs = self._process_crs(data, crs) if self.geo else None
#     397 self.project = project
#     398 self.coastline = coastline
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/converter.py:650, in HoloViewsConverter._process_crs(self, data, crs)
#     647     _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     649 try:
# --> 650     return process_crs(_crs)
#     651 except ValueError:
#     652     # only raise error if crs was specified in kwargs
#     653     if crs:
#
# File ~/anaconda3/envs/EdX/lib/python3.10/site-packages/hvplot/util.py:234, in process_crs(crs)
#     232     import pyproj
#     233 except ImportError:
# --> 234     raise ImportError('Geographic projection support requires GeoViews, pyproj and cartopy.')
#     236 if crs is None:
#     237     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires GeoViews, pyproj and cartopy.
