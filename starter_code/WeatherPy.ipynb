# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 568

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity =  city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | college
# Processing Record 2 of Set 1 | gidole
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | ampasimanolotra
# City not found. Skipping...
# Processing Record 5 of Set 1 | khovd
# Processing Record 6 of Set 1 | richards bay
# Processing Record 7 of Set 1 | san antonio de pale
# Processing Record 8 of Set 1 | margaret river
# Processing Record 9 of Set 1 | cairns city
# City not found. Skipping...
# Processing Record 10 of Set 1 | guarapari
# Processing Record 11 of Set 1 | udachny
# Processing Record 12 of Set 1 | hobyo
# Processing Record 13 of Set 1 | puerto natales
# Processing Record 14 of Set 1 | edinburgh of the seven seas
# Processing Record 15 of Set 1 | blackmans bay
# Processing Record 16 of Set 1 | basco
# Processing Record 17 of Set 1 | newman
# Processing Record 18 of Set 1 | grytviken
# Processing Record 19 of Set 1 | carutapera
# Processing Record 20 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 21 of Set 1 | port-aux-francais
# Processing Record 22 of Set 1 | nova sintra
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | mana
# Processing Record 25 of Set 1 | angra do heroismo
# Processing Record 26 of Set 1 | hawaiian paradise park
# Processing Record 27 of Set 1 | holualoa
# Processing Record 28 of Set 1 | whitehorse
# Processing Record 29 of Set 1 | adamstown
# Processing Record 30 of Set 1 | tura
# Processing Record 31 of Set 1 | waitangi
# Processing Record 32 of Set 1 | belel
# Processing Record 33 of Set 1 | teknaf
# Processing Record 34 of Set 1 | bardai
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | tarawa
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | coquimbo
# Processing Record 40 of Set 1 | tarinkot
# Processing Record 41 of Set 1 | cidade velha
# Processing Record 42 of Set 1 | fale old settlement
# Processing Record 43 of Set 1 | hadibu
# Processing Record 44 of Set 1 | aykhal
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | las khorey
# Processing Record 47 of Set 1 | palmer
# Processing Record 48 of Set 1 | tiksi
# Processing Record 49 of Set 1 | antonio enes
# Processing Record 50 of Set 1 | isafjordur
# Processing Record 0 of Set 2 | huambo
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | pelabuhanratu
# Processing Record 3 of Set 2 | gulf shores
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | kostomuksha
# Processing Record 6 of Set 2 | kunming
# Processing Record 7 of Set 2 | argostolion
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | weno
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | fort bragg
# Processing Record 12 of Set 2 | talnakh
# Processing Record 13 of Set 2 | okhotsk
# Processing Record 14 of Set 2 | enewetak
# Processing Record 15 of Set 2 | pasighat
# Processing Record 16 of Set 2 | keflavik
# Processing Record 17 of Set 2 | avarua
# Processing Record 18 of Set 2 | mount pearl
# Processing Record 19 of Set 2 | gebeit
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 22 of Set 2 | vilyuysk
# Processing Record 23 of Set 2 | vorgashor
# Processing Record 24 of Set 2 | kasongo
# Processing Record 25 of Set 2 | le mars
# Processing Record 26 of Set 2 | port mathurin
# Processing Record 27 of Set 2 | mccook
# Processing Record 28 of Set 2 | laguna
# Processing Record 29 of Set 2 | huarmey
# Processing Record 30 of Set 2 | jinshi
# Processing Record 31 of Set 2 | ternate
# Processing Record 32 of Set 2 | kuqa
# Processing Record 33 of Set 2 | oroqen zizhiqi
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | tolanaro
# Processing Record 36 of Set 2 | ancud
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | ketchikan
# Processing Record 39 of Set 2 | khandyga
# Processing Record 40 of Set 2 | sarupathar
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | stanley
# Processing Record 43 of Set 2 | ushuaia
# Processing Record 44 of Set 2 | nola
# Processing Record 45 of Set 2 | saldanha
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | boa vista
# Processing Record 48 of Set 2 | svoge
# Processing Record 49 of Set 2 | san patricio
# Processing Record 0 of Set 3 | borgarnes
# Processing Record 1 of Set 3 | sarandi del yi
# Processing Record 2 of Set 3 | shalqar
# Processing Record 3 of Set 3 | berdyansk
# Processing Record 4 of Set 3 | devils lake
# Processing Record 5 of Set 3 | rio grande
# Processing Record 6 of Set 3 | plainview
# Processing Record 7 of Set 3 | kingston
# Processing Record 8 of Set 3 | kurumkan
# Processing Record 9 of Set 3 | essaouira
# Processing Record 10 of Set 3 | itoman
# Processing Record 11 of Set 3 | antofagasta
# Processing Record 12 of Set 3 | ribeira brava
# Processing Record 13 of Set 3 | jining
# Processing Record 14 of Set 3 | ormara
# Processing Record 15 of Set 3 | port lincoln
# Processing Record 16 of Set 3 | egilsstadir
# Processing Record 17 of Set 3 | touros
# Processing Record 18 of Set 3 | atafu village
# Processing Record 19 of Set 3 | yakeshi
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | ad darb
# Processing Record 22 of Set 3 | crane
# Processing Record 23 of Set 3 | novozybkov
# Processing Record 24 of Set 3 | soio
# Processing Record 25 of Set 3 | la ronge
# Processing Record 26 of Set 3 | balkanabat
# Processing Record 27 of Set 3 | uturoa
# Processing Record 28 of Set 3 | alice springs
# Processing Record 29 of Set 3 | st. john's
# Processing Record 30 of Set 3 | vadso
# Processing Record 31 of Set 3 | gordonvale
# Processing Record 32 of Set 3 | charlotte amalie
# Processing Record 33 of Set 3 | naze
# Processing Record 34 of Set 3 | manaure
# Processing Record 35 of Set 3 | coahuayana de hidalgo
# Processing Record 36 of Set 3 | khorixas
# Processing Record 37 of Set 3 | bodo
# Processing Record 38 of Set 3 | dudinka
# Processing Record 39 of Set 3 | fort mcmurray
# Processing Record 40 of Set 3 | hermiston
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | gadzhiyevo
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | governador valadares
# Processing Record 45 of Set 3 | gopalpur
# Processing Record 46 of Set 3 | pariaman
# Processing Record 47 of Set 3 | sitka
# Processing Record 48 of Set 3 | vilyuchinsk
# Processing Record 49 of Set 3 | north bend
# Processing Record 0 of Set 4 | jiayuguan
# Processing Record 1 of Set 4 | santarem
# Processing Record 2 of Set 4 | qaqortoq
# Processing Record 3 of Set 4 | papatowai
# Processing Record 4 of Set 4 | mbala
# Processing Record 5 of Set 4 | narrabri
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | olonkinbyen
# Processing Record 8 of Set 4 | preobrazheniye
# Processing Record 9 of Set 4 | brookings
# Processing Record 10 of Set 4 | la passe
# Processing Record 11 of Set 4 | port blair
# Processing Record 12 of Set 4 | constantia
# Processing Record 13 of Set 4 | praia da vitoria
# Processing Record 14 of Set 4 | bamboo flat
# Processing Record 15 of Set 4 | margate
# Processing Record 16 of Set 4 | al kharijah
# Processing Record 17 of Set 4 | hardys memories of africa
# City not found. Skipping...
# Processing Record 18 of Set 4 | forster
# Processing Record 19 of Set 4 | sierra grande
# Processing Record 20 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 4 | kangding
# Processing Record 22 of Set 4 | asifabad
# Processing Record 23 of Set 4 | longyearbyen
# Processing Record 24 of Set 4 | pyt-yakh
# Processing Record 25 of Set 4 | evergreen
# Processing Record 26 of Set 4 | plauen
# Processing Record 27 of Set 4 | latur
# Processing Record 28 of Set 4 | mukalla
# Processing Record 29 of Set 4 | suining
# Processing Record 30 of Set 4 | bredasdorp
# Processing Record 31 of Set 4 | barauli
# Processing Record 32 of Set 4 | bilibino
# Processing Record 33 of Set 4 | utrik
# Processing Record 34 of Set 4 | howard springs
# Processing Record 35 of Set 4 | novosilikatnyy
# Processing Record 36 of Set 4 | paphos
# Processing Record 37 of Set 4 | badger
# Processing Record 38 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 4 | paide
# Processing Record 40 of Set 4 | cabo san lucas
# Processing Record 41 of Set 4 | aasiaat
# Processing Record 42 of Set 4 | espargos
# City not found. Skipping...
# Processing Record 43 of Set 4 | flin flon
# Processing Record 44 of Set 4 | luanda
# Processing Record 45 of Set 4 | luzilandia
# Processing Record 46 of Set 4 | naryn
# Processing Record 47 of Set 4 | ihosy
# Processing Record 48 of Set 4 | hamilton
# Processing Record 49 of Set 4 | hammerfest
# Processing Record 0 of Set 5 | mhamid
# Processing Record 1 of Set 5 | tobelo
# Processing Record 2 of Set 5 | kargasok
# Processing Record 3 of Set 5 | nuku'alofa
# Processing Record 4 of Set 5 | port shepstone
# Processing Record 5 of Set 5 | el granada
# Processing Record 6 of Set 5 | cockburn town
# Processing Record 7 of Set 5 | dar naim
# City not found. Skipping...
# Processing Record 8 of Set 5 | okha
# Processing Record 9 of Set 5 | tsiombe
# Processing Record 10 of Set 5 | west island
# Processing Record 11 of Set 5 | bafq
# Processing Record 12 of Set 5 | hermanus
# Processing Record 13 of Set 5 | gromitz
# Processing Record 14 of Set 5 | altamont
# Processing Record 15 of Set 5 | bilicenii vechi
# Processing Record 16 of Set 5 | ksar chellala
# Processing Record 17 of Set 5 | nemuro
# Processing Record 18 of Set 5 | kavaratti
# Processing Record 19 of Set 5 | mount isa
# Processing Record 20 of Set 5 | lebu
# Processing Record 21 of Set 5 | port saint john's
# Processing Record 22 of Set 5 | sawankhalok
# Processing Record 23 of Set 5 | yuzhno-kurilsk
# Processing Record 24 of Set 5 | sarangani
# Processing Record 25 of Set 5 | tommot
# Processing Record 26 of Set 5 | trenton
# Processing Record 27 of Set 5 | solnechnyy
# Processing Record 28 of Set 5 | byron bay
# Processing Record 29 of Set 5 | anadyr
# Processing Record 30 of Set 5 | tazacorte
# Processing Record 31 of Set 5 | yorkton
# Processing Record 32 of Set 5 | tafuna
# Processing Record 33 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 34 of Set 5 | codrington
# Processing Record 35 of Set 5 | el nido
# Processing Record 36 of Set 5 | juan griego
# Processing Record 37 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 38 of Set 5 | darnah
# Processing Record 39 of Set 5 | saint-felicien
# Processing Record 40 of Set 5 | villa gesell
# Processing Record 41 of Set 5 | leer
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | rundu
# Processing Record 44 of Set 5 | carmo do cajuru
# Processing Record 45 of Set 5 | christchurch
# Processing Record 46 of Set 5 | wailua homesteads
# Processing Record 47 of Set 5 | tefe
# Processing Record 48 of Set 5 | kralendijk
# Processing Record 49 of Set 5 | sedrata
# Processing Record 0 of Set 6 | el calafate
# Processing Record 1 of Set 6 | ust-nera
# Processing Record 2 of Set 6 | prince george
# Processing Record 3 of Set 6 | kachug
# Processing Record 4 of Set 6 | am djarass
# City not found. Skipping...
# Processing Record 5 of Set 6 | okondja
# Processing Record 6 of Set 6 | bujumbura
# Processing Record 7 of Set 6 | colonia
# Processing Record 8 of Set 6 | hastings
# Processing Record 9 of Set 6 | malango
# Processing Record 10 of Set 6 | midvagur
# Processing Record 11 of Set 6 | concordia
# Processing Record 12 of Set 6 | chigorodo
# Processing Record 13 of Set 6 | malinyi
# Processing Record 14 of Set 6 | charcas
# Processing Record 15 of Set 6 | kerikeri
# Processing Record 16 of Set 6 | kapa'a
# Processing Record 17 of Set 6 | nagqu
# Processing Record 18 of Set 6 | springbok
# Processing Record 19 of Set 6 | wewak
# Processing Record 20 of Set 6 | saint-francois
# Processing Record 21 of Set 6 | ulety
# Processing Record 22 of Set 6 | jwaneng
# Processing Record 23 of Set 6 | gurupi
# Processing Record 24 of Set 6 | sao joao da barra
# Processing Record 25 of Set 6 | mayfield heights
# Processing Record 26 of Set 6 | zhanaozen
# Processing Record 27 of Set 6 | lucea
# Processing Record 28 of Set 6 | dryden
# Processing Record 29 of Set 6 | arraial do cabo
# Processing Record 30 of Set 6 | chimore
# Processing Record 31 of Set 6 | cabedelo
# Processing Record 32 of Set 6 | sitangkai
# Processing Record 33 of Set 6 | markovo
# Processing Record 34 of Set 6 | lodja
# Processing Record 35 of Set 6 | mogocha
# Processing Record 36 of Set 6 | al khums
# Processing Record 37 of Set 6 | timimoun
# Processing Record 38 of Set 6 | san jose del guaviare
# Processing Record 39 of Set 6 | lagos de moreno
# Processing Record 40 of Set 6 | bikenibeu village
# Processing Record 41 of Set 6 | heunghae
# Processing Record 42 of Set 6 | maragogi
# Processing Record 43 of Set 6 | recani
# Processing Record 44 of Set 6 | saipan
# Processing Record 45 of Set 6 | mimizan
# Processing Record 46 of Set 6 | wolmaransstad
# Processing Record 47 of Set 6 | hafar al-batin
# Processing Record 48 of Set 6 | chilecito
# Processing Record 49 of Set 6 | ad dabbah
# Processing Record 0 of Set 7 | katsuren-haebaru
# Processing Record 1 of Set 7 | dubinino
# Processing Record 2 of Set 7 | bismarck
# Processing Record 3 of Set 7 | nar'yan-mar
# Processing Record 4 of Set 7 | klyuchi
# Processing Record 5 of Set 7 | mckinleyville
# Processing Record 6 of Set 7 | hilo
# Processing Record 7 of Set 7 | broken hill
# Processing Record 8 of Set 7 | kharp
# Processing Record 9 of Set 7 | raeren
# Processing Record 10 of Set 7 | gimbi
# Processing Record 11 of Set 7 | sungailiat
# Processing Record 12 of Set 7 | vila velha
# Processing Record 13 of Set 7 | invercargill
# Processing Record 14 of Set 7 | jagtial
# Processing Record 15 of Set 7 | chui
# Processing Record 16 of Set 7 | ust-tsilma
# Processing Record 17 of Set 7 | mili
# Processing Record 18 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 19 of Set 7 | lihue
# Processing Record 20 of Set 7 | alofi
# Processing Record 21 of Set 7 | nyrob
# Processing Record 22 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 23 of Set 7 | yigo village
# Processing Record 24 of Set 7 | funafuti
# Processing Record 25 of Set 7 | svatove
# Processing Record 26 of Set 7 | katsuura
# Processing Record 27 of Set 7 | wielen
# Processing Record 28 of Set 7 | polyarnyy
# Processing Record 29 of Set 7 | kirkland lake
# Processing Record 30 of Set 7 | shenjiamen
# Processing Record 31 of Set 7 | taulaga
# Processing Record 32 of Set 7 | lere
# Processing Record 33 of Set 7 | laayoune
# Processing Record 34 of Set 7 | neryungri
# Processing Record 35 of Set 7 | namibe
# Processing Record 36 of Set 7 | callao
# Processing Record 37 of Set 7 | tari
# Processing Record 38 of Set 7 | acapulco de juarez
# Processing Record 39 of Set 7 | walvis bay
# Processing Record 40 of Set 7 | remire-montjoly
# Processing Record 41 of Set 7 | meizhou
# Processing Record 42 of Set 7 | cidreira
# Processing Record 43 of Set 7 | livingston
# Processing Record 44 of Set 7 | parambu
# Processing Record 45 of Set 7 | igarka
# Processing Record 46 of Set 7 | hasaki
# Processing Record 47 of Set 7 | comandante fontana
# Processing Record 48 of Set 7 | kijang
# Processing Record 49 of Set 7 | pedra branca
# Processing Record 0 of Set 8 | happy valley-goose bay
# Processing Record 1 of Set 8 | pisco
# Processing Record 2 of Set 8 | namtsy
# Processing Record 3 of Set 8 | ras gharib
# City not found. Skipping...
# Processing Record 4 of Set 8 | nampula
# Processing Record 5 of Set 8 | norfolk county
# Processing Record 6 of Set 8 | island harbour
# Processing Record 7 of Set 8 | eydhafushi
# Processing Record 8 of Set 8 | i-n-salah
# Processing Record 9 of Set 8 | queenstown
# Processing Record 10 of Set 8 | nueva gerona
# Processing Record 11 of Set 8 | outokumpu
# Processing Record 12 of Set 8 | tabou
# Processing Record 13 of Set 8 | parral
# Processing Record 14 of Set 8 | zahedan
# Processing Record 15 of Set 8 | susuman
# Processing Record 16 of Set 8 | nanzhang chengguanzhen
# Processing Record 17 of Set 8 | mandera
# Processing Record 18 of Set 8 | flying fish cove
# Processing Record 19 of Set 8 | vargem grande do sul
# Processing Record 20 of Set 8 | nikolayevsk-on-amure
# Processing Record 21 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 22 of Set 8 | kialla
# Processing Record 23 of Set 8 | alo
# Processing Record 24 of Set 8 | ballina
# Processing Record 25 of Set 8 | muhos
# Processing Record 26 of Set 8 | pacific grove
# Processing Record 27 of Set 8 | pitimbu
# Processing Record 28 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 29 of Set 8 | mersing
# Processing Record 30 of Set 8 | acarau
# Processing Record 31 of Set 8 | amarante do maranhao
# Processing Record 32 of Set 8 | qarah bagh
# Processing Record 33 of Set 8 | kingsland
# Processing Record 34 of Set 8 | afaahiti
# Processing Record 35 of Set 8 | jianshui
# Processing Record 36 of Set 8 | veshenskaya
# Processing Record 37 of Set 8 | manokwari
# Processing Record 38 of Set 8 | amga
# Processing Record 39 of Set 8 | kedougou
# Processing Record 40 of Set 8 | kuusamo
# Processing Record 41 of Set 8 | neiafu
# Processing Record 42 of Set 8 | fortaleza
# Processing Record 43 of Set 8 | kidal
# Processing Record 44 of Set 8 | benguela
# Processing Record 45 of Set 8 | sinabang
# Processing Record 46 of Set 8 | minas de marcona
# Processing Record 47 of Set 8 | charlestown
# Processing Record 48 of Set 8 | najran
# Processing Record 49 of Set 8 | pokrovsk
# Processing Record 0 of Set 9 | mossel bay
# Processing Record 1 of Set 9 | glenwood
# Processing Record 2 of Set 9 | konstantinovka
# Processing Record 3 of Set 9 | dombarovskiy
# Processing Record 4 of Set 9 | santana
# Processing Record 5 of Set 9 | mejit
# Processing Record 6 of Set 9 | lake wales
# Processing Record 7 of Set 9 | zaragoza
# Processing Record 8 of Set 9 | boppard
# Processing Record 9 of Set 9 | salym
# Processing Record 10 of Set 9 | amahai
# Processing Record 11 of Set 9 | moravsky krumlov
# Processing Record 12 of Set 9 | marco
# Processing Record 13 of Set 9 | tazovsky
# Processing Record 14 of Set 9 | uyuni
# Processing Record 15 of Set 9 | kununurra
# Processing Record 16 of Set 9 | inda silase
# Processing Record 17 of Set 9 | kecel
# Processing Record 18 of Set 9 | kruisfontein
# Processing Record 19 of Set 9 | san matias
# Processing Record 20 of Set 9 | tarakan
# Processing Record 21 of Set 9 | alesund
# Processing Record 22 of Set 9 | stephenville
# Processing Record 23 of Set 9 | nanping
# Processing Record 24 of Set 9 | shira
# Processing Record 25 of Set 9 | qianzhou
# Processing Record 26 of Set 9 | leticia
# Processing Record 27 of Set 9 | siuna
# Processing Record 28 of Set 9 | al mayadin
# Processing Record 29 of Set 9 | karratha
# Processing Record 30 of Set 9 | inarajan village
# Processing Record 31 of Set 9 | onega
# Processing Record 32 of Set 9 | trapani
# Processing Record 33 of Set 9 | saint-philippe
# Processing Record 34 of Set 9 | luderitz
# Processing Record 35 of Set 9 | wamba
# Processing Record 36 of Set 9 | mont-dore
# Processing Record 37 of Set 9 | lagos
# Processing Record 38 of Set 9 | chernyshevskiy
# Processing Record 39 of Set 9 | hirtshals
# Processing Record 40 of Set 9 | la libertad
# Processing Record 41 of Set 9 | wuhai
# Processing Record 42 of Set 9 | canutama
# Processing Record 43 of Set 9 | cestos city
# Processing Record 44 of Set 9 | anabar
# City not found. Skipping...
# Processing Record 45 of Set 9 | douglas
# Processing Record 46 of Set 9 | masaka
# Processing Record 47 of Set 9 | poronaysk
# Processing Record 48 of Set 9 | yamada
# Processing Record 49 of Set 9 | sarmiento
# Processing Record 0 of Set 10 | ar ruways
# Processing Record 1 of Set 10 | lucapa
# Processing Record 2 of Set 10 | fuglafjordur
# Processing Record 3 of Set 10 | jiuquan
# Processing Record 4 of Set 10 | motygino
# Processing Record 5 of Set 10 | roma
# Processing Record 6 of Set 10 | rawson
# Processing Record 7 of Set 10 | sheridan
# Processing Record 8 of Set 10 | dunedin
# Processing Record 9 of Set 10 | labytnangi
# Processing Record 10 of Set 10 | kwang binh
# Processing Record 11 of Set 10 | alajarvi
# Processing Record 12 of Set 10 | bathsheba
# Processing Record 13 of Set 10 | illizi
# Processing Record 14 of Set 10 | harper
# Processing Record 15 of Set 10 | hami
# Processing Record 16 of Set 10 | akureyri
# Processing Record 17 of Set 10 | kalabo
# Processing Record 18 of Set 10 | bodaybo
# Processing Record 19 of Set 10 | pointe aux piments
# Processing Record 20 of Set 10 | cole harbour
# Processing Record 21 of Set 10 | usogorsk
# Processing Record 22 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 23 of Set 10 | ostroleka
# Processing Record 24 of Set 10 | thunder bay
# Processing Record 25 of Set 10 | trinidad
# Processing Record 26 of Set 10 | gemena
# Processing Record 27 of Set 10 | daru
# Processing Record 28 of Set 10 | santa ana
# Processing Record 29 of Set 10 | olyokminsk
# Processing Record 30 of Set 10 | puerto lempira
# Processing Record 31 of Set 10 | lusaka
# Processing Record 32 of Set 10 | el charco
# Processing Record 33 of Set 10 | suva
# Processing Record 34 of Set 10 | swift current
# Processing Record 35 of Set 10 | kilifi
# Processing Record 36 of Set 10 | korla
# Processing Record 37 of Set 10 | labrador city
# Processing Record 38 of Set 10 | bengbu
# Processing Record 39 of Set 10 | ubari
# Processing Record 40 of Set 10 | olinda
# Processing Record 41 of Set 10 | birjand
# Processing Record 42 of Set 10 | male
# Processing Record 43 of Set 10 | klaksvik
# Processing Record 44 of Set 10 | la'ie
# Processing Record 45 of Set 10 | kalymnos
# Processing Record 46 of Set 10 | cortland
# Processing Record 47 of Set 10 | howrah
# Processing Record 48 of Set 10 | rikaze
# Processing Record 49 of Set 10 | salinas
# Processing Record 0 of Set 11 | puerto baquerizo moreno
# Processing Record 1 of Set 11 | ambalangoda
# Processing Record 2 of Set 11 | fukumitsu
# Processing Record 3 of Set 11 | nadi
# Processing Record 4 of Set 11 | fort riley north
# Processing Record 5 of Set 11 | tagiura
# Processing Record 6 of Set 11 | taiynsha
# Processing Record 7 of Set 11 | wucheng
# Processing Record 8 of Set 11 | colonel hill
# Processing Record 9 of Set 11 | marion
# Processing Record 10 of Set 11 | isla del bosque
# Processing Record 11 of Set 11 | jacobabad
# Processing Record 12 of Set 11 | grants
# Processing Record 13 of Set 11 | mexico
# Processing Record 14 of Set 11 | marvejols
# Processing Record 15 of Set 11 | revelstoke
# Processing Record 16 of Set 11 | verkhnevilyuysk
# Processing Record 17 of Set 11 | port-vila
# Processing Record 18 of Set 11 | atoyatempan
# Processing Record 19 of Set 11 | svetlyy
# Processing Record 20 of Set 11 | quellon
# Processing Record 21 of Set 11 | rayachoti
# Processing Record 22 of Set 11 | de aar
# Processing Record 23 of Set 11 | konosha
# Processing Record 24 of Set 11 | williams lake
# Processing Record 25 of Set 11 | murray bridge
# Processing Record 26 of Set 11 | bastia
# Processing Record 27 of Set 11 | alaghsas
# Processing Record 28 of Set 11 | trairi
# Processing Record 29 of Set 11 | mount gambier
# Processing Record 30 of Set 11 | vanimo
# Processing Record 31 of Set 11 | palpa
# Processing Record 32 of Set 11 | caruthersville
# Processing Record 33 of Set 11 | fruita
# Processing Record 34 of Set 11 | shetpe
# Processing Record 35 of Set 11 | geroskipou
# City not found. Skipping...
# Processing Record 36 of Set 11 | belyy yar
# Processing Record 37 of Set 11 | san rafael
# Processing Record 38 of Set 11 | portland
# Processing Record 39 of Set 11 | mizan teferi
# Processing Record 40 of Set 11 | birzebbuga
# Processing Record 41 of Set 11 | fort st. john
# Processing Record 42 of Set 11 | ivdel'
# Processing Record 43 of Set 11 | isle of arran
# City not found. Skipping...
# Processing Record 44 of Set 11 | kuanda
# Processing Record 45 of Set 11 | aberdeen
# Processing Record 46 of Set 11 | guadix
# Processing Record 47 of Set 11 | shiyan
# Processing Record 48 of Set 11 | castillos
# Processing Record 49 of Set 11 | beira
# Processing Record 0 of Set 12 | tadine
# Processing Record 1 of Set 12 | haiku-pauwela
# Processing Record 2 of Set 12 | chonchi
# Processing Record 3 of Set 12 | ola
# Processing Record 4 of Set 12 | birao
# Processing Record 5 of Set 12 | zeya
# Processing Record 6 of Set 12 | ovejas
# Processing Record 7 of Set 12 | thinadhoo
# Processing Record 8 of Set 12 | cadale
# Processing Record 9 of Set 12 | al bardiyah
# Processing Record 10 of Set 12 | lazaro cardenas
# Processing Record 11 of Set 12 | port augusta
# Processing Record 12 of Set 12 | maintirano
# Processing Record 13 of Set 12 | parkes
# Processing Record 14 of Set 12 | zhabei
# City not found. Skipping...
# Processing Record 15 of Set 12 | revda
# Processing Record 16 of Set 12 | galle
# Processing Record 17 of Set 12 | sumbawa besar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          547
# Lat           547
# Lng           547
# Max Temp      547
# Humidity      547
# Cloudiness    547
# Wind Speed    547
# Country       547
# Date          547
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       college  64.8569 -147.8028     48.15        91         100
# 1        gidole   5.6500   37.3667     59.00        80          64
# 2        kodiak  57.7900 -152.4072     53.11        58          40
# 3         khovd  48.0056   91.6419     53.04        37          52
# 4  richards bay -28.7830   32.0377     61.32        75           1
#
#    Wind Speed Country        Date
# 0        9.22      US  1694031402
# 1        1.66      ET  1694031402
# 2        6.91      US  1694031403
# 3        8.55      MN  1694031403
# 4        3.98      ZA  1694031403

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             college  64.8569 -147.8028     48.15        91         100
# 1              gidole   5.6500   37.3667     59.00        80          64
# 2              kodiak  57.7900 -152.4072     53.11        58          40
# 3               khovd  48.0056   91.6419     53.04        37          52
# 4        richards bay -28.7830   32.0377     61.32        75           1
#
#          Wind Speed Country        Date
# City_ID
# 0              9.22      US  1694031402
# 1              1.66      ET  1694031402
# 2              6.91      US  1694031403
# 3              8.55      MN  1694031403
# 4              3.98      ZA  1694031403

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], c = 'blue', edgecolors= 'black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Latitude v Max Temperature (2023-06-01)')
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], c = 'blue', edgecolors= 'black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude v Humidity (2023-06-01)')
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], c = 'blue', edgecolors= 'black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude v Cloudiness (2023-06-01)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], c = 'blue', edgecolors= 'black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude v Wind Speed (2023-06-01)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def plot_lin(df, condition1, condition2):
    slope, int, r, p, st_err = linregress(df[condition1], df[condition2])
    fit = slope * df[condition1] + int
    str_fit = f'y = {slope:.2f}x + {int:.2f}'
    plt.scatter(df[condition1], df[condition2])
    plt.xlabel(condition1)
    plt.ylabel(condition2)
    plt.plot(df[condition1], fit, color = 'red')
    print(f'The r value is: {r}')
    
    xmin, xmax, ymin, ymax = plt.axis()
    plt.text(xmin + 10, ymin + 10, str_fit, color = 'red')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        college  64.8569 -147.8028     48.15        91         100
# 1         gidole   5.6500   37.3667     59.00        80          64
# 2         kodiak  57.7900 -152.4072     53.11        58          40
# 3          khovd  48.0056   91.6419     53.04        37          52
# 8        udachny  66.4167  112.4000     30.45       100         100
#
#          Wind Speed Country        Date
# City_ID
# 0              9.22      US  1694031402
# 1              1.66      ET  1694031402
# 2              6.91      US  1694031403
# 3              8.55      MN  1694031403
# 8             18.19      RU  1694031404

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 4               richards bay -28.7830   32.0377     61.32        75
# 5        san antonio de pale  -1.4014    5.6325     73.98        85
# 6             margaret river -33.9500  115.0667     44.49        73
# 7                  guarapari -20.6667  -40.4975     71.89        90
# 10            puerto natales -51.7236  -72.4875     41.94        72
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 4                 1        3.98      ZA  1694031403
# 5                61        9.13      GQ  1694031403
# 6                 5        5.73      AU  1694031404
# 7               100       13.67      BR  1694031404
# 10               50       11.05      CL  1694031405

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_lin(northern_hemi_df, 'Lat', 'Max Temp')
# Out:
# The r value is: -0.7189864982778215

# %%
# Linear regression on Southern Hemisphere
plot_lin(southern_hemi_df, 'Lat', 'Max Temp')
# Out:
# The r value is: 0.8488195540361898

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, as latitude increases, max temp decreases.  This makes sense because more northern countries above the northern hemisphere have colder temperatures.  However, as the southern hemisphere latitude increases, max temperature increases.  This also makes sense because below the southern hemisphere, temperature increases with latitude. Both correlations are pretty strong.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_lin(northern_hemi_df, 'Lat', 'Humidity')
# Out:
# The r value is: 0.10290439033550061

# %%
# Southern Hemisphere
plot_lin(southern_hemi_df, 'Lat', 'Humidity')
# Out:
# The r value is: -0.03820690487756372

# %% [markdown]
# **Discussion about the linear relationship:** **Discussion about the linear relationship:** Both correlations are pretty weak (r = .10 for northern hemisphere, r = -.03 for southern hemisphere). Therefore, latitude and humidity have a very weak correlation.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_lin(northern_hemi_df, 'Lat', 'Cloudiness')
# Out:
# The r value is: 0.0022778575719749096

# %%
# Southern Hemisphere
plot_lin(southern_hemi_df, 'Lat', 'Cloudiness')
# Out:
# The r value is: -0.24110528757163138

# %% [markdown]
# **Discussion about the linear relationship:** There is a much larger correlation in the southern hemisphere than there is in the northern hemisphere. Latitude and cloudiness have a stronger relationship in the south than in the north.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_lin(northern_hemi_df, 'Lat', 'Wind Speed')
# Out:
# The r value is: -0.026609417889075723

# %%
# Southern Hemisphere
plot_lin(southern_hemi_df, 'Lat', 'Wind Speed')
# Out:
# The r value is: -0.25985038468084026

# %% [markdown]
# **Discussion about the linear relationship:** The r values are really small for both northern and southern hemispheres (-.02 and -.25 respectively). Therefore, latitude and wind speed have very weak correlations.
